# %% [markdown]
# # <p style="text-align: center;"> <span style="color:yellowgreen"> Lab 1 - MM driving around the block </span></p>

# %% [markdown]
# So far, we have seen how to use the ROS debugging commands and create ROS packages, publisher and subscriber nodes, and launch files.
#
# The *goal* of this lab is to create a package that makes the MM (robot) drive in a square both in
# **1. The MM simulation** and in
# **2. The physical MM (robot).** 🦆
#
# A good foundation to start on is Ex2 where we made the turtlesim move in a square.

# %% [markdown]
# ## <p style="text-align: center;"> <span style="color:coral"> Objectives </span></p>
# 1. Create a package. The name of the package must be **lab1**.
#
# 2. Create one node (one python script):
#
# 	a. The name of the node must be **mmdriver.py**
# 	b. This node must publish commands for the MM to do a square
#
#
# 3. A launch file to start all nodes. The name of the launch file must be **lab1.launch**.
#
# ### ROS Package
# Your package will depend on rospy, roscpp, std_msgs, geometry_msgs and duckietown_msgs.
#
# You can name the package as you wish.
#
# ### ROS Nodes
# You will create one node in your package.
# A template is provided.
#
# **Square Node**:
# This node will be similar to the your Ex2 node.
# It should make the MM move in a square.
# The node should perform the following:
# - Drive straight for 1m then stop for 5 seconds.
# DEMONSTRATE this before moving on.
# - Turn 90 degrees, drive 1m then stop for 5 seconds.
# DEMONSTRATE this before moving on.
# - Turn 90 degrees
# - Repeat THESE EXACT COMMANDS twice more to make something like a square.
#
# Note that in the real MM, it **will not be a perfect square**.
# However, in the MM simulator, it **must be a perfect square**.
# For the real MM, only the first two corners are graded.
# DEMONSTRATE this.
#
# - **Note**- ROS nodes will start at different times, so consider adding a slight delay before publishing commands.
# Add a delay of at least 10 seconds in the beginning of your node python script.
# The simulator takes some time to start, the delay prevents you from starting your node before the simulator is ready.
# See the template.
#
#
# ### ROS Launch file
# The launch file must start everything needed to accomplish the exercise objectives.
# Your launch file must start
# 1. Your Square Node
# 2. Rqt graph
# 3. Rostopic echo MM pose topic output
#
# ## Notebooks information
#
# There are 2 notebooks covering:
# - Running the MM simulator (lab1a)
# - Running in the real MM (lab1b)
# 	- **It takes time to run the first time in the MM as well as update your MM sim code**
# 	- **Plan accordingly. If you are having issues come to office hours or ask for help in class**
#
# You can use these detailed instructions to complete this assignment.

# %% [markdown]
# ## <p style="text-align: center;"> <span style="color:coral;">Submission </span></p>
# **Only one of the group member will create the tag**
#
# 1. Check which files changed
# ```bash
# git status
# ```
# 2. Add them to this staged commit
# ```bash
# git add -A
# ```
# 3. Make the commit
# ```bash
# git commit -m 'your message for the commit'
# ```
# 4. Push it to your repo on GitHub
# ```bash
# git push
# ```
# Up to this point, your git should be updated. The next commands are for the final exercise or lab submission
#
# 5. Tag based lab1.
# ```bash
# git tag lab1
# ```
# 6. Push the tag to Github
# ```bash
# git push origin lab1
# ```
# 7. Verify on Github.com that your submission is there, in the correct tag
#
# ### <p style="text-align: center;">Rubric</p>
#
# - Package creation 5%
# - Calibrate the wheels 5%
# - Launch file 5%
# - Git tag 5%
# - MM driver node 70% (**DEMONSTRATE IN THE LAB**)
# 	- Demonstrate the MM moves as described above in the simulator 20% (Demonstrate this first before moving to the real MM)
# 		- Algorithm 10 %
# 		- Accuracy 10 %
# 	- Demonstrate the MM moves as described above in the lab 50%
# 		-  10% accuracy at first corner (-0.5% for every 12.5 cm from corner)
# 		-  10% accuracy at second corner (-0.5% for every 25 cm from corner)
# 		-  20% running same commands again to complete square (not graded on accuracy)
# 		-  10% stops after last square corner
#
# - Lab report 10% (only one member submits on Canvas)
# 	1. Provide name of group members and a link to your lab repo
# 	2. A description of each group member role in completing the assignment
# 	3. What do the inputs to `wheels_cmd` look like?
#       	- Use the joystick dt-joystick-demo to figure it out.
#       	- Describe the components of the message (data types) and their purpose.
# 	4. Which node do you think accepts this calibration value and adjusts commands as needed? Justify your answer.
# 	5. What difficulties did you have in tuning your robot to make a pattern?
# 	6. Do you think we can drive the MM reliably around a block without feedback from the camera? Why or why not?
